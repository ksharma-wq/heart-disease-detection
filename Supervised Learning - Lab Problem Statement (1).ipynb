# %% [markdown]
# ## Learning Outcomes
# - Exploratory data analysis & preparing the data for model building.
# - Machine Learning - Supervised Learning Classification
#   - Logistic Regression
#   - Naive bayes Classifier
#   - KNN Classifier
#   - Decision Tree Classifier
#   - Random Forest Classifier
#   - Ensemble methods
# - Training and making predictions using different classification models.
# - Model evaluation

# %% [markdown]
# ## Objective:
# - The Classification goal is to predict “heart disease” in a person with regards to different factors given.
#
# ## Context:
# - Heart disease is one of the leading causes of death for people of most races in the US. At least 1 of 3 key risk factors for heart disease: high blood pressure, high cholesterol, and smoking.
# - Detecting and preventing the factors that have the greatest impact on heart disease is very important in healthcare. Machine learning methods may detect "patterns" from the data and can predict whether a patient is suffering from any heart disease or not..
#
# ## Dataset Information
#
# #### Source: https://www.kaggle.com/datasets/kamilpytlak/personal-key-indicators-of-heart-disease?datasetId=1936563&sortBy=voteCount
# Originally, the dataset come from the CDC and is a major part of the Behavioral Risk Factor Surveillance System (BRFSS), which conducts annual telephone surveys to gather data on the health status of U.S. residents.
#
# This dataset consists of eighteen columns
# - HeartDisease: Respondents that have ever reported having coronary heart disease (CHD) or myocardial infarction (MI)
# - BMI: Body Mass Index (BMI)
# - Smoking: smoked at least 100 cigarettes in your entire life
# - AlcoholDrinking: Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week
# - Stroke:Ever had a stroke?
# - PhysicalHealth: physical health, which includes physical illness and injury
# - MentalHealth: for how many days during the past 30 days was your mental health not good?
# - DiffWalking: Do you have serious difficulty walking or climbing stairs?
# - Sex: male or female?
# - AgeCategory: Fourteen-level age category
# - Race: Imputed race/ethnicity value
# - Diabetic: diabetes?
# - PhysicalActivity: Adults who reported doing physical activity or exercise during the past 30 days other than their regular job
# - GenHealth: Would you say that in general your health is good, fine or excellent?
# - SleepTime: On average, how many hours of sleep do you get in a 24-hour period?
# - Asthma: you had asthma?
# - KidneyDisease: Not including kidney stones, bladder infection or incontinence, were you ever told you had kidney disease?
# - SkinCancer: Ever had skin cancer?

# %% [markdown]
# ### 1. Importing Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder

import warnings 
warnings.filterwarnings('ignore')

from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### 2. Load the dataset and display a sample of five rows of the data frame.

# %%
import pandas as pd

df = pd.read_csv("heart_2020_cleaned.csv")

# %% [markdown]
# ### 3. Check the shape of the data (number of rows and columns). Check the general information about the dataframe using the .info() method.

# %%
#shape of the data 
df.shape
# Out:
# (319795, 18)

# %%
#info of the data
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  str
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  str
#  3   AlcoholDrinking   319795 non-null  str
#  4   Stroke            319795 non-null  str
#  5   PhysicalHealth    319795 non-null  int64
#  6   MentalHealth      319795 non-null  int64
#  7   DiffWalking       319795 non-null  str
#  8   Sex               319795 non-null  str
#  9   AgeCategory       319795 non-null  str
#  10  Race              319795 non-null  str
#  11  Diabetic          319795 non-null  str
#  12  PhysicalActivity  319795 non-null  str
#  13  GenHealth         319795 non-null  str
#  14  SleepTime         319795 non-null  int64
#  15  Asthma            319795 non-null  str
#  16  KidneyDisease     319795 non-null  str
# ...

# %% [markdown]
# ### 4. Check the statistical summary of the dataset and write your inferences.

# %%
df.describe().T
# Out:
#                    count       mean       std    min    25%    50%    75%  \
# BMI             319795.0  28.325399  6.356100  12.02  24.03  27.34  31.42
# PhysicalHealth  319795.0   3.371710  7.950850   0.00   0.00   0.00   2.00
# MentalHealth    319795.0   3.898366  7.955235   0.00   0.00   0.00   3.00
# SleepTime       319795.0   7.097075  1.436007   1.00   6.00   7.00   8.00
#
#                   max
# BMI             94.85
# PhysicalHealth  30.00
# MentalHealth    30.00
# SleepTime       24.00

# %%
df.describe(include='O').T
# Out:
#                    count unique        top    freq
# HeartDisease      319795      2         No  292422
# Smoking           319795      2         No  187887
# AlcoholDrinking   319795      2         No  298018
# Stroke            319795      2         No  307726
# DiffWalking       319795      2         No  275385
# Sex               319795      2     Female  167805
# AgeCategory       319795     13      65-69   34151
# Race              319795      6      White  245212
# Diabetic          319795      4         No  269653
# PhysicalActivity  319795      2        Yes  247957
# GenHealth         319795      5  Very good  113858
# Asthma            319795      2         No  276923
# KidneyDisease     319795      2         No  308016
# SkinCancer        319795      2         No  289976

# %% [markdown]
# #it has been shown that white race peoples are more prone to have  heart disease than other race peoples

# %% [markdown]
# ### 5. Check the percentage of missing values in each column of the data frame. Drop the missing values if there are any.

# %%
df.isnull().sum()/len(df)*100
# Out:
# HeartDisease        0.0
# BMI                 0.0
# Smoking             0.0
# AlcoholDrinking     0.0
# Stroke              0.0
# PhysicalHealth      0.0
# MentalHealth        0.0
# DiffWalking         0.0
# Sex                 0.0
# AgeCategory         0.0
# Race                0.0
# Diabetic            0.0
# PhysicalActivity    0.0
# GenHealth           0.0
# SleepTime           0.0
# Asthma              0.0
# KidneyDisease       0.0
# SkinCancer          0.0
# dtype: float64

# %% [markdown]
# ### 6. Check if there are any duplicate rows. If any drop them and check the shape of the dataframe after dropping duplicates.

# %%
len(df[df.duplicated()])
# Out:
# 18078

# %%
df.drop_duplicates(inplace=True)

# %%
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# ### 7. Check the distribution of the target variable (i.e. 'HeartDisease') and write your observations.

# %%
df['HeartDisease'].value_counts()/len(df)*100
# Out:
# HeartDisease
# No     90.964712
# Yes     9.035288
# Name: count, dtype: float64

# %%
df['HeartDisease'].value_counts().plot(kind='pie', autopct ='%1.2f%%')
# Out:
# <Axes: >

# %% [markdown]
# Data shows that less than 10% respondeds have heart disease

# %% [markdown]
# ### 8. Visualize the distribution of the target column 'Heart disease' with respect to various categorical features and write your observations.

# %%
categorial_features = df.select_dtypes(include=[np.object_])
categorial_features.columns
# Out:
# Index(['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking',
#        'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity',
#        'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='str')

# %%
i = 1
plt.figure(figsize = (40,35))

for feature in categorial_features:
    plt.subplot(6,3,i)
    sns.countplot(x = feature, hue = 'HeartDisease', data=df)
    i += 1

# %% [markdown]
# Figures are showing that peoples having age 70 and above are more prone to have heartdiesease and white race peoples are more prone to have heartdiesease

# %% [markdown]
# ### 9. Check the unique categories in the column 'Diabetic'. Replace 'Yes (during pregnancy)' as 'Yes' and 'No, borderline diabetes' as 'No'.

# %%
df.Diabetic.unique()
# Out:
# <StringArray>
# ['Yes', 'No', 'No, borderline diabetes', 'Yes (during pregnancy)']
# Length: 4, dtype: str

# %%
df['Diabetic'] = df['Diabetic'].replace({'Yes (during pregnancy)':'Yes','No, borderline diabetes':'No'})

# %%
df['Diabetic'].value_counts()
# Out:
# Diabetic
# No     258572
# Yes     43145
# Name: count, dtype: int64

# %%
df.Diabetic.unique()
# Out:
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %% [markdown]
# ### 10. For the target column 'HeartDiease', Replace 'No' as 0 and 'Yes' as 1.

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# No     274456
# Yes     27261
# Name: count, dtype: int64

# %%
df['HeartDisease'] = df['HeartDisease'].replace({'Yes':1,'No':0})

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 0    274456
# 1     27261
# Name: count, dtype: int64

# %% [markdown]
# ### 11. Label Encode the columns "AgeCategory", "Race", and "GenHealth". Encode the rest of the columns using dummy encoding approach.

# %%
## Lebal encode categorial variables using 'AgeCategory', 'Race', 'GenHealth' Label encoder
#select object datatype variables

object_type_variable = [i for i in df[['AgeCategory','Race','GenHealth']] if df.dtypes[i] == object]
print(object_type_variable)

le = LabelEncoder()

def encoder (df):
    for i in object_type_variable:
        q = le.fit_transform(df[i].astype(str))
        df[i] = q 
        df[i] = df[i].astype(int)
encoder(df)
# Out:
# []

# %%
#dumy incode rest of the columns, since they have binary enteries. 'yes' or 'no'
df = pd.get_dummies(df, drop_first= True)
df.head()
# Out:
#      BMI  PhysicalHealth  MentalHealth  SleepTime  HeartDisease_1  \
# 0  16.60               3            30          5           False
# 1  20.34               0             0          7           False
# 2  26.58              20            30          8           False
# 3  24.21               0             0          6           False
# 4  23.71              28             0          8           False
#
#    Smoking_Yes  AlcoholDrinking_Yes  Stroke_Yes  DiffWalking_Yes  Sex_Male  \
# 0         True                False       False            False     False
# 1        False                False        True            False     False
# 2         True                False       False            False      True
# 3        False                False       False            False     False
# 4        False                False       False             True     False
#
#    ...  Race_White  Diabetic_Yes  PhysicalActivity_Yes  GenHealth_Fair  \
# ...

# %%
print(df.columns.tolist())
# Out:
# ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime', 'HeartDisease_1', 'Smoking_Yes', 'AlcoholDrinking_Yes', 'Stroke_Yes', 'DiffWalking_Yes', 'Sex_Male', 'AgeCategory_25-29', 'AgeCategory_30-34', 'AgeCategory_35-39', 'AgeCategory_40-44', 'AgeCategory_45-49', 'AgeCategory_50-54', 'AgeCategory_55-59', 'AgeCategory_60-64', 'AgeCategory_65-69', 'AgeCategory_70-74', 'AgeCategory_75-79', 'AgeCategory_80 or older', 'Race_Asian', 'Race_Black', 'Race_Hispanic', 'Race_Other', 'Race_White', 'Diabetic_Yes', 'PhysicalActivity_Yes', 'GenHealth_Fair', 'GenHealth_Good', 'GenHealth_Poor', 'GenHealth_Very good', 'Asthma_Yes', 'KidneyDisease_Yes', 'SkinCancer_Yes']

# %% [markdown]
# ### 12. Store the target column (i.e.'HeartDisease') in the y variable and the rest of the columns in the X variable.

# %%
# Split X and y

X = df.drop('HeartDisease_1', axis=1)
y = df['HeartDisease_1']

# %% [markdown]
# ### 13. Split the dataset into two parts (i.e. 70% train and 30% test) and print the shape of the train and test data

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size= 0.2)

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (241373, 35) (60344, 35)
# (241373,) (60344,)

# %% [markdown]
# ### 14. Standardize the numerical columns using Standard Scalar approach for both train and test data.

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

# Numerical columns
num_cols = ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']

# Convert to float before assigning scaled values
X_train[num_cols] = X_train[num_cols].astype(float)
X_test[num_cols] = X_test[num_cols].astype(float)

# Fit scaler only on training data
X_train[num_cols] = ss.fit_transform(X_train[num_cols])

# Use the same scaler on test data
X_test[num_cols] = ss.transform(X_test[num_cols])

print("Standardization completed successfully!")
# Out:
# Standardization completed successfully!

# %%
X_train.head()
# Out:
#              BMI  PhysicalHealth  MentalHealth  SleepTime  Smoking_Yes  \
# 159453 -0.414006       -0.438549     -0.506746   0.623706         True
# 124275 -0.927810       -0.438549     -0.261000  -0.057380        False
# 118142  0.296344        1.405442      0.721985   3.348048        False
# 757     0.887528       -0.438549     -0.506746  -1.419551        False
# 239993  0.444914       -0.438549     -0.506746  -1.419551         True
#
#         AlcoholDrinking_Yes  Stroke_Yes  DiffWalking_Yes  Sex_Male  \
# 159453                 True       False             True      True
# 124275                False       False            False      True
# 118142                False        True             True     False
# 757                   False       False             True     False
# 239993                False       False            False      True
#
#         AgeCategory_25-29  ...  Race_White  Diabetic_Yes  \
# 159453              False  ...        True          True
# ...

# %% [markdown]
# ### 15. Write a function.
# - i) Which can take the model and data as inputs.
# - ii) Fits the model with the train data.
# - iii) Makes predictions on the test set.
# - iv) Returns the Accuracy Score.

# %%
#Load the model
logreg_model = LogisticRegression()
knn_model = KNeighborsClassifier()
nb_model = GaussianNB()
dt_model = DecisionTreeClassifier()
rf_model = RandomForestClassifier()
adaboost_model = AdaBoostClassifier()
gradboost_model = GradientBoostingClassifier()

# %%
#Train the model
logreg_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
nb_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
adaboost_model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
gradboost_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
from sklearn.ensemble import GradientBoostingClassifier

gradientboost_model = GradientBoostingClassifier(random_state=42)

gradientboost_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
# make predictions

logreg_preds = logreg_model.predict(X_test)
knn_preds = knn_model.predict(X_test)
nb_preds = nb_model.predict(X_test)
dt_preds = dt_model.predict(X_test)
rf_preds = rf_model.predict(X_test)
adaboost_preds = adaboost_model.predict(X_test)
gradientboost_preds = gradientboost_model.predict(X_test)

# %%
print("Logistic regression", round(accuracy_score(y_test, logreg_preds), 3))
print("KNN", round(accuracy_score(y_test, knn_preds), 3))
print("Naive Bayes", round(accuracy_score(y_test, nb_preds), 3))
print("Decision Tree", round(accuracy_score(y_test, dt_preds), 3))
print("Random Forest", round(accuracy_score(y_test, rf_preds), 3))
print("Adaboost", round(accuracy_score(y_test, adaboost_preds), 3))
print("Gradient Boost", round(accuracy_score(y_test, gradientboost_preds), 3))
# Out:
# Logistic regression 0.91
# KNN 0.9
# Naive Bayes 0.725
# Decision Tree 0.854
# Random Forest 0.896
# Adaboost 0.909
# Gradient Boost 0.91

# %% [markdown]
# ### 16. Use the function and train a Logistic regression, KNN, Naive Bayes, Decision tree, Random Forest, Adaboost, GradientBoost, and Stacked Classifier models and make predictions on test data and evaluate the models, compare and write your conclusions and steps to be taken in future in order to improve the accuracy of the model.

# %%
# Stacking model

from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

stacked_model = StackingClassifier(
    estimators=[
        ('logreg', logreg_model),
        ('knn', knn_model),
        ('nb', nb_model),
        ('dt', dt_model),
        ('rf', rf_model),
        ('adaboost', adaboost_model),
        ('gradientboost', gradientboost_model)
    ],
    final_estimator=LogisticRegression()
)

# Train
stacked_model.fit(X_train, y_train)

# Predict
stacked_preds = stacked_model.predict(X_test)

# Evaluate
print('Stacked Model', accuracy_score(y_test, stacked_preds))
# Out:
# Stacked Model 0.9095353307702506

# %%
import joblib

# Save the trained Stacked Model
joblib.dump(stacked_model, "backend/heart_model.pkl")

# Save the feature names/order
joblib.dump(list(X.columns), "backend/feature_names.pkl")

print("Model saved successfully!")
print("Feature names saved successfully!")
# Out:
# Model saved successfully!
# Feature names saved successfully!

# %% [markdown]
# ### Conclusion

# %% [raw]
# In this case study, we have attempted to training and making predictions using different classification models such as Supervised Learning Classification, Logistic Regression, Naive bayes Classifier, KNN Classifier, Decision Tree Classifier, Random Forest Classifier and Ensemble methods
#
# Further it has been identified that we got highest accuracy percentage from three models respectvely Logistic regression (0.913), Adaboost (0.913) and Gradient boost (0.914).

# %% [markdown]
# ----
# ## Happy Learning:)
# ----
